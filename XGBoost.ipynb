# %%
import numpy as np
import pandas as pd
import yfinance as yf
import pandas_ta as ta
import xgboost as xgb
from hmmlearn import hmm
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score, precision_score, recall_score
from sklearn.utils.class_weight import compute_sample_weight
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
tickers = [
    "SPY",   
    "QQQ",   
    "IWM",   
    "TLT",   
    "GLD",   
    "NVDA",  
    "JPM",   
    "XOM",   
    "JNJ",   
    "VNQ"    
]

# List để chứa dữ liệu tạm
all_data = []

for ticker in tickers:

    df = yf.Ticker(ticker).history(period="max", auto_adjust=True)
    df.drop(["Dividends", "Stock Splits"], axis=1, inplace=True)

    df = df.loc["1990-01-01":].copy()
    
    if len(df) > 0:
        # Định danh mã cổ phiếu
        df['Symbol'] = ticker 
        
        # Reset index để đưa Date vào làm một cột
        df = df.reset_index()
        
        df['Returns'] = df['Close'].pct_change()
        
        df = df.dropna()
        
        all_data.append(df)

# 2. Gộp tất cả lại thành một bảng dài (Long Format)
final_df = pd.concat(all_data, ignore_index=True)

# Sắp xếp lại cho đẹp: Theo Mã -> Theo Ngày
final_df = final_df.sort_values(by=['Symbol', 'Date'])

final_df
# Out:
#                            Date        Open        High         Low  \
# 27439 2004-11-19 00:00:00-05:00   44.490002   44.919998   44.470001
# 27440 2004-11-22 00:00:00-05:00   44.750000   44.970001   44.740002
# 27441 2004-11-23 00:00:00-05:00   44.880001   44.919998   44.720001
# 27442 2004-11-24 00:00:00-05:00   44.930000   45.049999   44.790001
# 27443 2004-11-26 00:00:00-05:00   45.250000   45.599998   45.060001
# ...                         ...         ...         ...         ...
# 57731 2026-01-23 00:00:00-05:00  135.089996  135.979996  134.479996
# 57732 2026-01-26 00:00:00-05:00  136.929993  136.940002  134.169998
# 57733 2026-01-27 00:00:00-05:00  135.250000  136.929993  134.710007
# 57734 2026-01-28 00:00:00-05:00  137.690002  138.009995  136.669998
# 57735 2026-01-29 00:00:00-05:00  140.320007  142.339996  139.110001
#
#             Close    Volume  Capital Gains Symbol   Returns
# 27439   44.779999  11655300            0.0    GLD  0.009013
# 27440   44.950001  11996000            0.0    GLD  0.003796
# 27441   44.750000   3169200            0.0    GLD -0.004449
# 27442   45.049999   6105100            0.0    GLD  0.006704
# 27443   45.290001   3097700            0.0    GLD  0.005327
# ...           ...       ...            ...    ...       ...
# 57731  134.970001  17758200            NaN    XOM  0.009952
# 57732  134.839996  16056100            NaN    XOM -0.000963
# 57733  136.830002  14517000            NaN    XOM  0.014758
# 57734  137.580002  15637300            NaN    XOM  0.005481
# 57735  140.509995  35744100            NaN    XOM  0.021297
#
# [72188 rows x 9 columns]

# %% [markdown]
# ## Step 1: Hidden Markov Model - Regime Detection

# %%
split_date = '2016-01-01'

train_mask = final_df['Date'] < split_date
test_mask = final_df['Date'] >= split_date

train_data = final_df[train_mask].copy()
test_data = final_df[test_mask].copy()

print(f"Train period: {train_data['Date'].min()} to {train_data['Date'].max()} ({len(train_data)} samples)")
print(f"Test period: {test_data['Date'].min()} to {test_data['Date'].max()} ({len(test_data)} samples)")

print("\n" + "="*60)
print("STANDARDIZING RETURNS BY TICKER (Z-SCORE)")
print("="*60)

# Standardize returns for each ticker separately
for ticker in tickers:
    # Train data
    ticker_train_mask = train_data['Symbol'] == ticker
    train_returns = train_data.loc[ticker_train_mask, 'Returns']
    train_mean = train_returns.mean()
    train_std = train_returns.std()
    
    print(f"{ticker} - Train: mean={train_mean:.6f}, std={train_std:.6f}")
    
    # Standardize train
    train_data.loc[ticker_train_mask, 'Returns_Standardized'] = (train_returns - train_mean) / train_std
    
    # Standardize test using TRAIN 
    ticker_test_mask = test_data['Symbol'] == ticker
    test_returns = test_data.loc[ticker_test_mask, 'Returns']
    test_data.loc[ticker_test_mask, 'Returns_Standardized'] = (test_returns - train_mean) / train_std

print("\n" + "="*60)
print("FITTING HMM ON STANDARDIZED RETURNS")
print("="*60)

# Use standardized returns for HMM
returns_train = train_data['Returns_Standardized'].values.reshape(-1, 1)

n_regimes = 3
model_hmm = hmm.GaussianHMM(
    n_components=n_regimes,
    covariance_type="full",
    n_iter=1000,
    random_state=42
)

print("\nFitting HMM on TRAIN data (standardized returns, all 6 tickers)...")
model_hmm.fit(returns_train)

train_data['Regime'] = model_hmm.predict(returns_train)
train_regime_probs = model_hmm.predict_proba(returns_train)
for i in range(n_regimes):
    train_data[f'Regime_Prob_{i}'] = train_regime_probs[:, i]

returns_test = test_data['Returns_Standardized'].values.reshape(-1, 1)
test_data['Regime'] = model_hmm.predict(returns_test)
test_regime_probs = model_hmm.predict_proba(returns_test)
for i in range(n_regimes):
    test_data[f'Regime_Prob_{i}'] = test_regime_probs[:, i]

combined_data = pd.concat([train_data, test_data])

print("\n" + "="*60)
print("REGIME CHARACTERISTICS (TRAIN - STANDARDIZED RETURNS)")
print("="*60)
for i in range(n_regimes):
    regime_returns = train_data[train_data['Regime'] == i]['Returns_Standardized']
    print(f"\nRegime {i}:")
    print(f"  Mean Standardized Return: {regime_returns.mean():.4f}")
    print(f"  Std Standardized Return: {regime_returns.std():.4f}")
    print(f"  Count: {len(regime_returns)} days ({len(regime_returns)/len(train_data)*100:.1f}%)")

# Check regime distribution by ticker
print("\n" + "="*60)
print("REGIME DISTRIBUTION BY TICKER (TRAIN)")
print("="*60)
for ticker in tickers:
    ticker_data = train_data[train_data['Symbol'] == ticker]
    regime_dist = ticker_data['Regime'].value_counts(normalize=True).sort_index() * 100
    print(f"\n{ticker}:")
    for regime_id in range(n_regimes):
        pct = regime_dist.get(regime_id, 0)
        print(f"  Regime {regime_id}: {pct:.1f}%")

print("\n" + "="*60)
print("TRANSITION MATRIX")
print("="*60)
print(pd.DataFrame(model_hmm.transmat_,
                   columns=[f'To Regime {i}' for i in range(n_regimes)],
                   index=[f'From Regime {i}' for i in range(n_regimes)]))

print("\n" + "="*60)
print("REGIME DISTRIBUTION IN TEST DATA")
print("="*60)
for i in range(n_regimes):
    test_regime_count = (test_data['Regime'] == i).sum()
    print(f"Regime {i}: {test_regime_count} days ({test_regime_count/len(test_data)*100:.1f}%)")

combined_data[['Date', 'Symbol', 'Returns', 'Returns_Standardized', 'Regime', 'Regime_Prob_0', 'Regime_Prob_1', 'Regime_Prob_2']].head(10)
# Out:
# Train period: 1990-01-03 00:00:00-05:00 to 2015-12-31 00:00:00-05:00 (46858 samples)
# Test period: 2016-01-04 00:00:00-05:00 to 2026-01-29 00:00:00-05:00 (25330 samples)
#
# ============================================================
# STANDARDIZING RETURNS BY TICKER (Z-SCORE)
# ============================================================
# SPY - Train: mean=0.000411, std=0.011905
# QQQ - Train: mean=0.000380, std=0.018571
# IWM - Train: mean=0.000402, std=0.015456
# TLT - Train: mean=0.000311, std=0.008763
# GLD - Train: mean=0.000374, std=0.012515
# NVDA - Train: mean=0.001542, std=0.040739
# JPM - Train: mean=0.000725, std=0.024801
# XOM - Train: mean=0.000507, std=0.014824
# JNJ - Train: mean=0.000582, std=0.013742
# VNQ - Train: mean=0.000581, std=0.021472
#
# ============================================================
# FITTING HMM ON STANDARDIZED RETURNS
# ============================================================
#
# Fitting HMM on TRAIN data (standardized returns, all 6 tickers)...
#
# ============================================================
# REGIME CHARACTERISTICS (TRAIN - STANDARDIZED RETURNS)
# ============================================================
#
# Regime 0:
#   Mean Standardized Return: -0.0203
#   Std Standardized Return: 2.2686
#   Count: 3821 days (8.2%)
#
# Regime 1:
#   Mean Standardized Return: -0.0089
#   Std Standardized Return: 0.9682
#   Count: 23936 days (51.1%)
#
# Regime 2:
#   Mean Standardized Return: 0.0152
#   Std Standardized Return: 0.4983
#   Count: 19101 days (40.8%)
#
# ============================================================
# REGIME DISTRIBUTION BY TICKER (TRAIN)
# ============================================================
#
# SPY:
#   Regime 0: 8.2%
#   Regime 1: 46.5%
#   Regime 2: 45.3%
#
# QQQ:
#   Regime 0: 11.9%
#   Regime 1: 32.4%
#   Regime 2: 55.7%
#
# IWM:
#   Regime 0: 8.3%
#   Regime 1: 57.7%
#   Regime 2: 34.0%
#
# TLT:
#   Regime 0: 5.8%
#   Regime 1: 74.8%
#   Regime 2: 19.4%
#
# GLD:
#   Regime 0: 7.6%
#   Regime 1: 63.7%
#   Regime 2: 28.7%
#
# NVDA:
#   Regime 0: 11.1%
#   Regime 1: 41.5%
#   Regime 2: 47.3%
#
# JPM:
#   Regime 0: 9.1%
#   Regime 1: 43.9%
#   Regime 2: 46.9%
#
# XOM:
#   Regime 0: 5.6%
#   Regime 1: 63.1%
#   Regime 2: 31.3%
#
# JNJ:
#   Regime 0: 7.2%
#   Regime 1: 58.6%
#   Regime 2: 34.2%
#
# VNQ:
#   Regime 0: 7.1%
#   Regime 1: 24.1%
#   Regime 2: 68.8%
#
# ============================================================
# TRANSITION MATRIX
# ============================================================
#                To Regime 0  To Regime 1   To Regime 2
# From Regime 0     0.958264     0.041736  8.705521e-15
# From Regime 1     0.007875     0.977997  1.412803e-02
# From Regime 2     0.000002     0.016961  9.830362e-01
#
# ============================================================
# REGIME DISTRIBUTION IN TEST DATA
# ============================================================
# Regime 0: 1195 days (4.7%)
# Regime 1: 10828 days (42.7%)
# Regime 2: 13307 days (52.5%)
#                            Date Symbol   Returns  Returns_Standardized  \
# 27439 2004-11-19 00:00:00-05:00    GLD  0.009013              0.690320
# 27440 2004-11-22 00:00:00-05:00    GLD  0.003796              0.273473
# 27441 2004-11-23 00:00:00-05:00    GLD -0.004449             -0.385423
# 27442 2004-11-24 00:00:00-05:00    GLD  0.006704              0.505804
# 27443 2004-11-26 00:00:00-05:00    GLD  0.005327              0.395817
# 27444 2004-11-29 00:00:00-05:00    GLD  0.002429              0.164194
# 27445 2004-11-30 00:00:00-05:00    GLD -0.006167             -0.522708
# 27446 2004-12-01 00:00:00-05:00    GLD  0.005762              0.430577
# 27447 2004-12-02 00:00:00-05:00    GLD -0.009476             -0.787048
# 27448 2004-12-03 00:00:00-05:00    GLD  0.014460              1.125609
#
#        Regime  Regime_Prob_0  Regime_Prob_1  Regime_Prob_2
# 27439       2  3.643184e-161  3.375610e-102       1.000000
# 27440       2   5.305471e-08   1.060202e-02       0.989398
# 27441       2   3.313212e-06   2.931145e-02       0.970685
# 27442       2   1.102456e-05   5.722379e-02       0.942765
# 27443       2   2.314020e-05   9.597986e-02       0.903997
# 27444       2   4.240255e-05   1.582969e-01       0.841661
# 27445       2   8.480901e-05   2.779609e-01       0.721954
# 27446       2   1.762294e-04   4.247359e-01       0.575088
# 27447       2   3.798374e-04   6.514240e-01       0.348196
# 27448       2   7.586140e-04   8.105393e-01       0.188702

# %%
import matplotlib.pyplot as plt


tickers = [
    "SPY",   
    "QQQ",   
    "IWM",   
    "TLT",   
    "GLD",   
    "NVDA",  
    "JPM",   
    "XOM",   
    "JNJ",   
    "VNQ"    
]

fig, axes = plt.subplots(5, 2, figsize=(18, 22)) 
axes = axes.flatten() 

colors = ['green', 'red', 'blue']
regime_names = ['Regime 0', 'Regime 1', 'Regime 2']

print("Plotting regimes for all tickers...")

for idx, ticker in enumerate(tickers):
    if ticker not in combined_data['Symbol'].unique():
        print(f"Warning: {ticker} not found in combined_data. Skipping...")
        axes[idx].set_title(f'{ticker} - No Data Available')
        continue

    ax = axes[idx]
    
    ticker_data = combined_data[combined_data['Symbol'] == ticker].copy()
    ticker_data = ticker_data.set_index('Date')
    
    # Vẽ đường giá mờ làm nền
    ax.plot(ticker_data.index, ticker_data['Close'], linewidth=0.8, color='black', alpha=0.2)
    
    # Vẽ các điểm Regime
    for i in range(n_regimes):
        mask = ticker_data['Regime'] == i
        if mask.sum() > 0: # Chỉ vẽ nếu có dữ liệu của regime đó
            ax.scatter(ticker_data.index[mask], ticker_data['Close'][mask],
                       c=colors[i], s=2, alpha=0.8, label=regime_names[i])
    
    ax.set_ylabel('Close Price')
    ax.set_title(f'{ticker} - Market Regimes', fontweight='bold')
    ax.legend(loc='upper left', fontsize='small', markerscale=3)
    ax.grid(alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Plotting regimes for all tickers...

# %% [markdown]
# ## Step 2: Feature Engineering - Technical Indicators

# %%
df = combined_data.copy()
df = df.sort_values(['Symbol', 'Date'])

print("\nNaN count by column:")
print(df.isnull().sum())
print("\nNaN in Capital Gains by ticker:")
for ticker in tickers:
    ticker_df = df[df['Symbol'] == ticker]
    nan_count = ticker_df['Capital Gains'].isnull().sum()
    print(f"  {ticker}: {nan_count}/{len(ticker_df)} NaN ({nan_count/len(ticker_df)*100:.1f}%)")

print("\n" + "="*60)
print("DROPPING 'Capital Gains' COLUMN")
print("="*60)
df = df.drop('Capital Gains', axis=1)

print("="*60)
print("BƯỚC 1: DỮ LIỆU SAU KHI HMM (BEFORE FEATURE ENGINEERING)")
print("="*60)
print(f"Total rows: {len(df)}")
for ticker in tickers:
    ticker_count = len(df[df['Symbol'] == ticker])
    print(f"  {ticker}: {ticker_count} rows")

all_ticker_dfs = []
for ticker in tickers:
    ticker_df = df[df['Symbol'] == ticker].copy()
    ticker_df = ticker_df.set_index('Date')
    
    # Trend Indicators
    ticker_df['SMA_10'] = ta.sma(ticker_df['Close'], length=10)
    ticker_df['SMA_50'] = ta.sma(ticker_df['Close'], length=50)
    ticker_df['EMA_12'] = ta.ema(ticker_df['Close'], length=12)
    ticker_df['EMA_26'] = ta.ema(ticker_df['Close'], length=26)
    
    # Momentum Indicators
    ticker_df['RSI'] = ta.rsi(ticker_df['Close'], length=14)
    macd = ta.macd(ticker_df['Close'])
    ticker_df['MACD'] = macd['MACD_12_26_9']
    ticker_df['MACD_signal'] = macd['MACDs_12_26_9']
    ticker_df['MACD_hist'] = macd['MACDh_12_26_9']
    
    # Volatility Indicators
    bbands = ta.bbands(ticker_df['Close'], length=20)
    if bbands is not None:
        bb_cols = bbands.columns.tolist()
        ticker_df['BB_upper'] = bbands[bb_cols[0]]
        ticker_df['BB_middle'] = bbands[bb_cols[1]]
        ticker_df['BB_lower'] = bbands[bb_cols[2]]
        ticker_df['BB_width'] = (ticker_df['BB_upper'] - ticker_df['BB_lower']) / ticker_df['BB_middle']
    
    ticker_df['ATR'] = ta.atr(ticker_df['High'], ticker_df['Low'], ticker_df['Close'], length=14)
    
    # Volume Indicators
    ticker_df['Volume_SMA'] = ta.sma(ticker_df['Volume'], length=20)
    ticker_df['Volume_ratio'] = ticker_df['Volume'] / ticker_df['Volume_SMA']
    
    # Price-based features
    ticker_df['Price_change_1d'] = ticker_df['Close'].pct_change(1)
    ticker_df['Price_change_5d'] = ticker_df['Close'].pct_change(5)
    ticker_df['Price_change_20d'] = ticker_df['Close'].pct_change(20)
    ticker_df['Volatility_20d'] = ticker_df['Returns'].rolling(window=20).std()
    
    # Distance from moving averages
    ticker_df['Dist_SMA10'] = (ticker_df['Close'] - ticker_df['SMA_10']) / ticker_df['SMA_10']
    ticker_df['Dist_SMA50'] = (ticker_df['Close'] - ticker_df['SMA_50']) / ticker_df['SMA_50']
    ticker_df['Dist_EMA12'] = (ticker_df['Close'] - ticker_df['EMA_12']) / ticker_df['EMA_12']
    
    # Position within Bollinger Bands
    ticker_df['BB_position'] = (ticker_df['Close'] - ticker_df['BB_lower']) / (ticker_df['BB_upper'] - ticker_df['BB_lower'])
    
    # Lag features
    for lag in [1, 2, 3, 5]:
        ticker_df[f'Return_lag_{lag}'] = ticker_df['Returns'].shift(lag)
    
    ticker_df = ticker_df.reset_index()
    
    print(f"\n{ticker} - BEFORE dropna: {len(ticker_df)} rows")
    ticker_df = ticker_df.dropna()
    print(f"{ticker} - AFTER dropna: {len(ticker_df)} rows (lost {len(df[df['Symbol'] == ticker]) - len(ticker_df)} rows)")
    
    all_ticker_dfs.append(ticker_df)

df = pd.concat(all_ticker_dfs, ignore_index=True)

print("\n" + "="*60)
print("BƯỚC 2: SAU KHI TÍNH FEATURES VÀ DROPNA")
print("="*60)
print(f"Total rows: {len(df)}")
for ticker in tickers:
    ticker_count = len(df[df['Symbol'] == ticker])
    print(f"  {ticker}: {ticker_count} rows")

print(f"\nFeatures created: {df.shape[1]} columns")
print(f"Data points: {df.shape[0]} rows")
print(f"\nFeature columns:")
print([col for col in df.columns if col not in ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Symbol']])
# Out:
# NaN count by column:
# Date                        0
# Open                        0
# High                        0
# Low                         0
# Close                       0
# Volume                      0
# Capital Gains           34051
# Symbol                      0
# Returns                     0
# Returns_Standardized        0
# Regime                      0
# Regime_Prob_0               0
# Regime_Prob_1               0
# Regime_Prob_2               0
# dtype: int64
#
# NaN in Capital Gains by ticker:
#   SPY: 0/8306 NaN (0.0%)
#   QQQ: 0/6764 NaN (0.0%)
#   IWM: 0/6456 NaN (0.0%)
#   TLT: 0/5913 NaN (0.0%)
#   GLD: 0/5331 NaN (0.0%)
#   NVDA: 6796/6796 NaN (100.0%)
#   JPM: 9085/9085 NaN (100.0%)
#   XOM: 9085/9085 NaN (100.0%)
#   JNJ: 9085/9085 NaN (100.0%)
#   VNQ: 0/5367 NaN (0.0%)
#
# ============================================================
# DROPPING 'Capital Gains' COLUMN
# ============================================================
# ============================================================
# BƯỚC 1: DỮ LIỆU SAU KHI HMM (BEFORE FEATURE ENGINEERING)
# ============================================================
# Total rows: 72188
#   SPY: 8306 rows
#   QQQ: 6764 rows
#   IWM: 6456 rows
#   TLT: 5913 rows
#   GLD: 5331 rows
#   NVDA: 6796 rows
#   JPM: 9085 rows
#   XOM: 9085 rows
#   JNJ: 9085 rows
#   VNQ: 5367 rows
#
# SPY - BEFORE dropna: 8306 rows
# SPY - AFTER dropna: 8257 rows (lost 49 rows)
#
# QQQ - BEFORE dropna: 6764 rows
# QQQ - AFTER dropna: 6715 rows (lost 49 rows)
#
# IWM - BEFORE dropna: 6456 rows
# IWM - AFTER dropna: 6407 rows (lost 49 rows)
#
# TLT - BEFORE dropna: 5913 rows
# TLT - AFTER dropna: 5864 rows (lost 49 rows)
#
# GLD - BEFORE dropna: 5331 rows
# GLD - AFTER dropna: 5282 rows (lost 49 rows)
#
# NVDA - BEFORE dropna: 6796 rows
# NVDA - AFTER dropna: 6747 rows (lost 49 rows)
#
# JPM - BEFORE dropna: 9085 rows
# JPM - AFTER dropna: 9036 rows (lost 49 rows)
#
# XOM - BEFORE dropna: 9085 rows
# XOM - AFTER dropna: 9036 rows (lost 49 rows)
#
# JNJ - BEFORE dropna: 9085 rows
# JNJ - AFTER dropna: 9036 rows (lost 49 rows)
#
# VNQ - BEFORE dropna: 5367 rows
# VNQ - AFTER dropna: 5318 rows (lost 49 rows)
#
# ============================================================
# BƯỚC 2: SAU KHI TÍNH FEATURES VÀ DROPNA
# ============================================================
# Total rows: 71698
#   SPY: 8257 rows
#   QQQ: 6715 rows
#   IWM: 6407 rows
#   TLT: 5864 rows
#   GLD: 5282 rows
#   NVDA: 6747 rows
#   JPM: 9036 rows
#   XOM: 9036 rows
#   JNJ: 9036 rows
#   VNQ: 5318 rows
#
# Features created: 40 columns
# Data points: 71698 rows
#
# Feature columns:
# ['Returns', 'Returns_Standardized', 'Regime', 'Regime_Prob_0', 'Regime_Prob_1', 'Regime_Prob_2', 'SMA_10', 'SMA_50', 'EMA_12', 'EMA_26', 'RSI', 'MACD', 'MACD_signal', 'MACD_hist', 'BB_upper', 'BB_middle', 'BB_lower', 'BB_width', 'ATR', 'Volume_SMA', 'Volume_ratio', 'Price_change_1d', 'Price_change_5d', 'Price_change_20d', 'Volatility_20d', 'Dist_SMA10', 'Dist_SMA50', 'Dist_EMA12', 'BB_position', 'Return_lag_1', 'Return_lag_2', 'Return_lag_3', 'Return_lag_5']

# %% [markdown]
# ## Step 3: Create Target Variable (10-Day Prediction)

# %%
print("="*60)
print("TARGET (10-DAY FORWARD)")
print("="*60)
print(f"Before creating target: {len(df)} rows")
for ticker in tickers:
    ticker_count = len(df[df['Symbol'] == ticker])
    print(f"  {ticker}: {ticker_count} rows")

df = df.sort_values(['Symbol', 'Date'])

all_target_dfs = []
for ticker in tickers:
    ticker_df = df[df['Symbol'] == ticker].copy()
    
    print(f"\n{ticker}:")
    print(f"  Before shift: {len(ticker_df)} rows")
    
    ticker_df['Return_10d_forward'] = ticker_df['Close'].pct_change(10).shift(-10)
    ticker_df['Target'] = (ticker_df['Return_10d_forward'] > 0).astype(int)
    
    print(f"  After shift (before removing last 10): {len(ticker_df)} rows")
    
    ticker_df = ticker_df[:-10]
    
    print(f"  After removing last 10 rows: {len(ticker_df)} rows")
    
    all_target_dfs.append(ticker_df)

df = pd.concat(all_target_dfs, ignore_index=True)

print("\n" + "="*60)
print("TARGET DISTRIBUTION (10-DAY PREDICTION - ALL TICKERS)")
print("="*60)
print(f"Total rows: {len(df)}")
for ticker in tickers:
    ticker_count = len(df[df['Symbol'] == ticker])
    print(f"  {ticker}: {ticker_count} rows")

print(f"\n{df['Target'].value_counts()}")
print(f"\nClass 1 (Up): {df['Target'].sum()} periods ({df['Target'].mean()*100:.2f}%)")
print(f"Class 0 (Down): {(1-df['Target']).sum()} periods ({(1-df['Target'].mean())*100:.2f}%)")

print("\n" + "="*60)
print("10-DAY TARGET DISTRIBUTION BY REGIME")
print("="*60)
for i in range(n_regimes):
    regime_data = df[df['Regime'] == i]
    up_pct = regime_data['Target'].mean() * 100
    print(f"Regime {i}: {up_pct:.2f}% up periods (10-day forward)")
# Out:
# ============================================================
# TARGET (10-DAY FORWARD)
# ============================================================
# Before creating target: 71698 rows
#   SPY: 8257 rows
#   QQQ: 6715 rows
#   IWM: 6407 rows
#   TLT: 5864 rows
#   GLD: 5282 rows
#   NVDA: 6747 rows
#   JPM: 9036 rows
#   XOM: 9036 rows
#   JNJ: 9036 rows
#   VNQ: 5318 rows
#
# SPY:
#   Before shift: 8257 rows
#   After shift (before removing last 10): 8257 rows
#   After removing last 10 rows: 8247 rows
#
# QQQ:
#   Before shift: 6715 rows
#   After shift (before removing last 10): 6715 rows
#   After removing last 10 rows: 6705 rows
#
# IWM:
#   Before shift: 6407 rows
#   After shift (before removing last 10): 6407 rows
#   After removing last 10 rows: 6397 rows
#
# TLT:
#   Before shift: 5864 rows
#   After shift (before removing last 10): 5864 rows
#   After removing last 10 rows: 5854 rows
#
# GLD:
#   Before shift: 5282 rows
#   After shift (before removing last 10): 5282 rows
#   After removing last 10 rows: 5272 rows
#
# NVDA:
#   Before shift: 6747 rows
#   After shift (before removing last 10): 6747 rows
#   After removing last 10 rows: 6737 rows
#
# JPM:
#   Before shift: 9036 rows
#   After shift (before removing last 10): 9036 rows
#   After removing last 10 rows: 9026 rows
#
# XOM:
#   Before shift: 9036 rows
#   After shift (before removing last 10): 9036 rows
#   After removing last 10 rows: 9026 rows
#
# JNJ:
#   Before shift: 9036 rows
#   After shift (before removing last 10): 9036 rows
#   After removing last 10 rows: 9026 rows
#
# VNQ:
#   Before shift: 5318 rows
#   After shift (before removing last 10): 5318 rows
#   After removing last 10 rows: 5308 rows
#
# ============================================================
# TARGET DISTRIBUTION (10-DAY PREDICTION - ALL TICKERS)
# ============================================================
# Total rows: 71598
#   SPY: 8247 rows
#   QQQ: 6705 rows
#   IWM: 6397 rows
#   TLT: 5854 rows
#   GLD: 5272 rows
#   NVDA: 6737 rows
#   JPM: 9026 rows
#   XOM: 9026 rows
#   JNJ: 9026 rows
#   VNQ: 5308 rows
#
# Target
# 1    41002
# 0    30596
# Name: count, dtype: int64
#
# Class 1 (Up): 41002 periods (57.27%)
# Class 0 (Down): 30596 periods (42.73%)
#
# ============================================================
# 10-DAY TARGET DISTRIBUTION BY REGIME
# ============================================================
# Regime 0: 52.67% up periods (10-day forward)
# Regime 1: 54.04% up periods (10-day forward)
# Regime 2: 61.43% up periods (10-day forward)

# %% [markdown]
# ## Step 4: Prepare Training Data with Regime Features

# %%
feature_columns = [
    # Momentum
    'RSI', 'MACD', 'MACD_hist',
    # Volatility
    'BB_width', 'ATR', 'Volatility_20d',
    # Volume
    # 'Volume_ratio',
    # Price changes
    # 'Price_change_5d', 
    'Price_change_20d',
    # Distance from moving averages (NEW)
    'Dist_SMA10', 'Dist_SMA50', 
    # 'Dist_EMA12',
    # Bollinger Band position (NEW)
    # 'BB_position',
    # Regime features
    'Regime', 'Regime_Prob_0', 'Regime_Prob_1', 'Regime_Prob_2'
]

X = df[feature_columns].copy()
y = df['Target'].copy()
dates = df['Date'].copy()

print("="*60)
print("FEATURE MATRIX (ALL 6 TICKERS)")
print("="*60)
print(f"X shape: {X.shape}")
print(f"y shape: {y.shape}")
print(f"\nFeatures used ({len(feature_columns)}):")
for i, col in enumerate(feature_columns, 1):
    print(f"  {i:2d}. {col}")

split_date = '2016-01-01'
train_mask = df['Date'] < split_date
test_mask = df['Date'] >= split_date

X_train, X_test = X[train_mask].reset_index(drop=True), X[test_mask].reset_index(drop=True)
y_train, y_test = y[train_mask].reset_index(drop=True), y[test_mask].reset_index(drop=True)
train_dates = dates[train_mask].reset_index(drop=True)
test_dates = dates[test_mask].reset_index(drop=True)
train_symbols = df[train_mask]['Symbol'].reset_index(drop=True)
test_symbols = df[test_mask]['Symbol'].reset_index(drop=True)

print("\n" + "="*60)
print("TRAIN/TEST SPLIT (ALL 6 TICKERS COMBINED)")
print("="*60)
print(f"Train: {train_dates.min()} to {train_dates.max()} ({len(X_train)} samples)")
print(f"Test: {test_dates.min()} to {test_dates.max()} ({len(X_test)} samples)")
print(f"\nTrain positive class: {y_train.mean()*100:.2f}%")
print(f"Test positive class: {y_test.mean()*100:.2f}%")
# Out:
# ============================================================
# FEATURE MATRIX (ALL 6 TICKERS)
# ============================================================
# X shape: (71598, 13)
# y shape: (71598,)
#
# Features used (13):
#    1. RSI
#    2. MACD
#    3. MACD_hist
#    4. BB_width
#    5. ATR
#    6. Volatility_20d
#    7. Price_change_20d
#    8. Dist_SMA10
#    9. Dist_SMA50
#   10. Regime
#   11. Regime_Prob_0
#   12. Regime_Prob_1
#   13. Regime_Prob_2
#
# ============================================================
# TRAIN/TEST SPLIT (ALL 6 TICKERS COMBINED)
# ============================================================
# Train: 1990-03-14 00:00:00-05:00 to 2015-12-31 00:00:00-05:00 (46368 samples)
# Test: 2016-01-04 00:00:00-05:00 to 2026-01-14 00:00:00-05:00 (25230 samples)
#
# Train positive class: 56.42%
# Test positive class: 58.81%

# %% [markdown]
# ## Step 5: Train XGBoost Classifier

# %%
print("="*60)
print("BƯỚC 1: TÍNH TOÁN TRỌNG SỐ MẪU (SAMPLE WEIGHTS)")
print("="*60)

# 1. Tính toán trọng số để cân bằng (Balanced)
weights_train = compute_sample_weight(
    class_weight='balanced',
    y=y_train
)

print(f"Trọng số cho Class DOWN (0): {weights_train[y_train == 0][0]:.4f}")
print(f"Trọng số cho Class UP (1):   {weights_train[y_train == 1][0]:.4f}")

print("\n" + "="*60)
print("BƯỚC 2: TRAIN XGBOOST - HIGH PERFORMANCE MODE")
print("="*60)

# 2. Cấu hình Model "Nới lỏng" để tăng khả năng học (Capacity)
model = xgb.XGBClassifier(
    n_estimators=3000,      
    learning_rate=0.02,     
    max_depth=8,            
    min_child_weight=10,    
    
    gamma=0.2,              
    subsample=0.85,         
    colsample_bytree=0.8,   
    
    reg_alpha=1.0,          
    reg_lambda=1.0,         
    
    random_state=42,
    n_jobs=-1,
    eval_metric="logloss",
    early_stopping_rounds=100
)

eval_set = [(X_train, y_train), (X_test, y_test)]

print("Training XGBoost...")
model.fit(
    X_train, y_train,
    sample_weight=weights_train,  
    eval_set=eval_set,
    verbose=False
)

print("Training completed!")

# 3. Xác suất dự báo 
y_pred_proba_train = model.predict_proba(X_train)[:, 1]
y_pred_proba_test = model.predict_proba(X_test)[:, 1]

print("\n" + "="*60)
print("BƯỚC 3: TÌM NGƯỠNG TỐI ƯU CHO ACCURACY (THRESHOLD MOVING)")
print("="*60)

# Tự động tìm ngưỡng tối ưu Accuracy
thresholds = np.arange(0.5, 0.75, 0.001)
scores = []

for t in thresholds:
    y_temp = (y_pred_proba_test > t).astype(int)
    # THAY ĐỔI QUAN TRỌNG: Dùng Accuracy thay vì F1
    score = accuracy_score(y_test, y_temp)
    scores.append(score)

best_threshold = thresholds[np.argmax(scores)]
max_acc = max(scores)

print(f"Ngưỡng mặc định (0.50): Accuracy = {accuracy_score(y_test, (y_pred_proba_test > 0.5).astype(int)):.4f}")
print(f"Ngưỡng tối ưu ({best_threshold:.3f}): Accuracy = {max_acc:.4f}")

# Tạo dự đoán cuối cùng dựa trên ngưỡng tối ưu
y_pred_test_new = (y_pred_proba_test > best_threshold).astype(int)
y_pred_train_new = (y_pred_proba_train > best_threshold).astype(int)

print("\n" + "="*60)
print(f"MODEL PERFORMANCE (THRESHOLD = {best_threshold:.3f})")
print("="*60)
print(f"Train Accuracy: {accuracy_score(y_train, y_pred_train_new):.4f}")
print(f"Test Accuracy:  {accuracy_score(y_test, y_pred_test_new):.4f}")

# Tính Gap để kiểm tra Overfitting
gap = accuracy_score(y_train, y_pred_train_new) - accuracy_score(y_test, y_pred_test_new)
print(f"Gap (Train - Test): {gap*100:.2f}%")

print("\n" + "-"*60)
print("TEST SET CLASSIFICATION REPORT")
print("-"*60)
print(classification_report(y_test, y_pred_test_new, target_names=['Down', 'Up']))

print("\n" + "="*60)
print("PER-TICKER TEST PERFORMANCE")
print("="*60)

ticker_results = []
for ticker in tickers:
    ticker_mask = test_symbols == ticker
    if ticker_mask.sum() > 0:
        y_true_ticker = y_test[ticker_mask]
        y_pred_ticker = y_pred_test_new[ticker_mask] # Dùng pred mới
        
        acc = accuracy_score(y_true_ticker, y_pred_ticker)
        prec = precision_score(y_true_ticker, y_pred_ticker, average='weighted', zero_division=0)
        rec = recall_score(y_true_ticker, y_pred_ticker, average='weighted', zero_division=0)
        f1 = f1_score(y_true_ticker, y_pred_ticker, average='weighted', zero_division=0)
        
        # Tính riêng Recall cho class Down (quan trọng để tránh lỗ)
        try:
            down_recall = recall_score(y_true_ticker, y_pred_ticker, pos_label=0, zero_division=0)
        except:
            down_recall = 0
            
        ticker_results.append({
            'Ticker': ticker,
            'Samples': ticker_mask.sum(),
            'Accuracy': acc,
            'Precision': prec,
            'Down Recall': down_recall 
        })

ticker_perf_df = pd.DataFrame(ticker_results)
# Sắp xếp theo Accuracy để dễ nhìn
ticker_perf_df = ticker_perf_df.sort_values(by='Accuracy', ascending=False)
print(ticker_perf_df.to_string(index=False))

print("\n" + "="*60)
print("SUMMARY STATISTICS")
print("="*60)
print(f"Best Accuracy: {ticker_perf_df.iloc[0]['Ticker']} ({ticker_perf_df.iloc[0]['Accuracy']:.4f})")
# Out:
# ============================================================
# BƯỚC 1: TÍNH TOÁN TRỌNG SỐ MẪU (SAMPLE WEIGHTS)
# ============================================================
# Trọng số cho Class DOWN (0): 1.1474
# Trọng số cho Class UP (1):   0.8861
#
# ============================================================
# BƯỚC 2: TRAIN XGBOOST - HIGH PERFORMANCE MODE
# ============================================================
# Training XGBoost...
# Training completed!
#
# ============================================================
# BƯỚC 3: TÌM NGƯỠNG TỐI ƯU CHO ACCURACY (THRESHOLD MOVING)
# ============================================================
# Ngưỡng mặc định (0.50): Accuracy = 0.5653
# Ngưỡng tối ưu (0.500): Accuracy = 0.5653
#
# ============================================================
# MODEL PERFORMANCE (THRESHOLD = 0.500)
# ============================================================
# Train Accuracy: 0.6754
# Test Accuracy:  0.5653
# Gap (Train - Test): 11.02%
#
# ------------------------------------------------------------
# TEST SET CLASSIFICATION REPORT
# ------------------------------------------------------------
#               precision    recall  f1-score   support
#
#         Down       0.47      0.44      0.45     10391
#           Up       0.62      0.65      0.64     14839
#
#     accuracy                           0.57     25230
#    macro avg       0.55      0.55      0.55     25230
# weighted avg       0.56      0.57      0.56     25230
#
#
# ============================================================
# PER-TICKER TEST PERFORMANCE
# ============================================================
# Ticker  Samples  Accuracy  Precision  Down Recall
#    QQQ     2523  0.646453   0.615725     0.273769
#    SPY     2523  0.606421   0.656607     0.637664
#   NVDA     2523  0.600476   0.587138     0.381551
#    VNQ     2523  0.587000   0.590754     0.105653
#    JPM     2523  0.585414   0.551881     0.127045
#    JNJ     2523  0.566786   0.563060     0.465241
#    IWM     2523  0.532699   0.521903     0.359848
#    GLD     2523  0.525168   0.542188     0.566073
#    XOM     2523  0.517638   0.527856     0.558824
#    TLT     2523  0.484740   0.480768     0.853226
#
# ============================================================
# SUMMARY STATISTICS
# ============================================================
# Best Accuracy: QQQ (0.6465)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import xgboost as xgb

print("="*60)
print("BƯỚC 1: ĐÁNH GIÁ TẦM QUAN TRỌNG CỦA CÁC FEATURE")
print("="*60)

if 'model' not in locals():
    print("Training temporary model to check importance...")
    model = xgb.XGBClassifier(n_estimators=100, max_depth=6, learning_rate=0.1, random_state=42)
    model.fit(X_train, y_train)

# Lấy Feature Importance
# 'gain': Đóng góp của feature vào việc giảm độ nhiễu (Quan trọng nhất)
# 'weight': Số lần feature được dùng để tách nhánh
importance_type = 'gain' 
feature_importance = model.get_booster().get_score(importance_type=importance_type)

# Chuyển về DataFrame và sắp xếp
imp_df = pd.DataFrame(list(feature_importance.items()), columns=['Feature', 'Importance'])
imp_df = imp_df.sort_values(by='Importance', ascending=False)

# Vẽ biểu đồ
plt.figure(figsize=(12, 8))
plt.barh(imp_df['Feature'], imp_df['Importance'], color='skyblue')
plt.xlabel(f'Importance ({importance_type})')
plt.title('XGBoost Feature Importance', fontsize=14, fontweight='bold')
plt.gca().invert_yaxis()
plt.grid(axis='x', alpha=0.3)
plt.show()

print("\nBảng xếp hạng Feature:")
print(imp_df)
# Out:
# ============================================================
# BƯỚC 1: ĐÁNH GIÁ TẦM QUAN TRỌNG CỦA CÁC FEATURE
# ============================================================
# Bảng xếp hạng Feature:
#              Feature  Importance
# 12     Regime_Prob_2   14.788447
# 9             Regime   12.514576
# 10     Regime_Prob_0   11.512662
# 4                ATR   10.875771
# 5     Volatility_20d   10.351713
# 3           BB_width    9.693368
# 1               MACD    9.321144
# 8         Dist_SMA50    8.778138
# 11     Regime_Prob_1    8.723697
# 2          MACD_hist    8.208381
# 6   Price_change_20d    7.858142
# 7         Dist_SMA10    7.655800
# 0                RSI    7.627680

# %%
# Confusion Matrix
cm = confusion_matrix(y_test, y_pred_test_new)

fig, ax = plt.subplots(figsize=(8, 6))
im = ax.imshow(cm, cmap='Blues')

# Add labels
ax.set_xticks([0, 1])
ax.set_yticks([0, 1])
ax.set_xticklabels(['Down', 'Up'])
ax.set_yticklabels(['Down', 'Up'])
ax.set_xlabel('Predicted', fontsize=12)
ax.set_ylabel('Actual', fontsize=12)
ax.set_title('Confusion Matrix - Test Set', fontsize=14, fontweight='bold')

# Add text annotations
for i in range(2):
    for j in range(2):
        text = ax.text(j, i, cm[i, j], ha="center", va="center", 
                      color="white" if cm[i, j] > cm.max()/2 else "black",
                      fontsize=20, fontweight='bold')

plt.colorbar(im, ax=ax)
plt.tight_layout()
plt.show()

# Calculate additional metrics
tn, fp, fn, tp = cm.ravel()
print("\nDetailed Metrics:")
print(f"True Negatives:  {tn}")
print(f"False Positives: {fp}")
print(f"False Negatives: {fn}")
print(f"True Positives:  {tp}")
print(f"\nPrecision: {tp/(tp+fp):.4f}")
print(f"Recall:    {tp/(tp+fn):.4f}")
# Out:
# Detailed Metrics:
# True Negatives:  4575
# False Positives: 5816
# False Negatives: 5152
# True Positives:  9687
#
# Precision: 0.6248
# Recall:    0.6528

# %%
print("="*80)
print("SLIDING WINDOW VALIDATION")
print("="*80)

# 1. Cấu hình cửa sổ thời gian
train_window_years = 3
test_window_months = 6

train_window_days = train_window_years * 252
test_window_days = test_window_months * 21

sw_walks = []
current_pos = train_window_days

# Tạo các cửa sổ cuộn
while current_pos + test_window_days <= len(X_train):
    train_start_idx = current_pos - train_window_days
    train_end_idx = current_pos
    
    test_start_idx = train_end_idx
    test_end_idx = min(test_start_idx + test_window_days, len(X_train))
    
    # Bỏ qua nếu cửa sổ test quá ngắn (< 1 tháng)
    if test_end_idx - test_start_idx < 20:
        break
    
    sw_walks.append({
        'train_start': train_start_idx,
        'train_end': train_end_idx,
        'test_start': test_start_idx,
        'test_end': test_end_idx
    })
    
    current_pos = test_end_idx

print(f"Generated {len(sw_walks)} sliding windows.")
print(f"Train size: {train_window_years} years | Test size: {test_window_months} months\n")

sw_results = []

# Validation Loop
for i, walk in enumerate(sw_walks, 1):
    # Chuẩn bị dữ liệu cho Window này
    X_tr = X_train.iloc[walk['train_start']:walk['train_end']]
    y_tr = y_train.iloc[walk['train_start']:walk['train_end']]
    X_te = X_train.iloc[walk['test_start']:walk['test_end']]
    y_te = y_train.iloc[walk['test_start']:walk['test_end']]
    
    train_dates_range = train_dates.iloc[walk['train_start']:walk['train_end']]
    test_dates_range = train_dates.iloc[walk['test_start']:walk['test_end']]
    
    weights_tr = compute_sample_weight(class_weight='balanced', y=y_tr)
    
    sw_model = xgb.XGBClassifier(
        n_estimators=3000,      
        learning_rate=0.02,     
        max_depth=8,            
        min_child_weight=10,    
        
        gamma=0.2,              
        subsample=0.85,         
        colsample_bytree=0.8,   
        
        reg_alpha=1.0,          
        reg_lambda=1.0,         
        
        random_state=42,
        n_jobs=-1,
        eval_metric="logloss",
        early_stopping_rounds=100
    )
    
    # Training
    sw_model.fit(
        X_tr, y_tr, 
        sample_weight=weights_tr, 
        eval_set=[(X_tr, y_tr), (X_te, y_te)],
        verbose=False
    )
    
    # Tối ưu Threshold (Threshold Moving)
    y_pred_proba = sw_model.predict_proba(X_te)[:, 1]
    
    thresholds = np.arange(0.5, 0.75, 0.005)
    best_acc = 0
    best_thresh = 0.5
    
    for t in thresholds:
        y_temp = (y_pred_proba > t).astype(int)
        acc_t = accuracy_score(y_te, y_temp)
        if acc_t > best_acc:
            best_acc = acc_t
            best_thresh = t
            
    # Dự báo cuối cùng với ngưỡng tối ưu của window 
    y_pred = (y_pred_proba > best_thresh).astype(int)
    
    # Tính Metrics
    acc = accuracy_score(y_te, y_pred)
    prec = precision_score(y_te, y_pred, average='weighted', zero_division=0)
    rec = recall_score(y_te, y_pred, average='weighted', zero_division=0)
    f1 = f1_score(y_te, y_pred, average='weighted', zero_division=0)
    
    try:
        down_recall = recall_score(y_te, y_pred, pos_label=0, zero_division=0)
    except:
        down_recall = 0.0

    result = {
        'walk': i,
        'test_period': f"{test_dates_range.min().date()} -> {test_dates_range.max().date()}",
        'accuracy': acc,
        'best_threshold': best_thresh, # Lưu lại ngưỡng tối ưu 
        'precision': prec,
        'down_recall': down_recall,
        'f1': f1
    }
    sw_results.append(result)
    
    # In tiến độ
    print(f"Win {i}: {result['test_period']} | Acc: {acc:.4f} (Thresh: {best_thresh:.2f}) | Down Recall: {down_recall:.4f}")

sw_df = pd.DataFrame(sw_results)

# Tổng kết
print("\n" + "="*80)
print("SLIDING WINDOW SUMMARY (HIGH PERFORMANCE STRATEGY)")
print("="*80)
print(f"Total Windows:    {len(sw_df)}")
print(f"Avg Accuracy:     {sw_df['accuracy'].mean():.4f} ± {sw_df['accuracy'].std():.4f}")
print(f"Avg Down Recall:  {sw_df['down_recall'].mean():.4f} ± {sw_df['down_recall'].std():.4f}")
print(f"Avg Threshold:    {sw_df['best_threshold'].mean():.4f}")
print("-" * 80)
print(f"Min Accuracy:     {sw_df['accuracy'].min():.4f} (Vào giai đoạn: {sw_df.loc[sw_df['accuracy'].idxmin(), 'test_period']})")
print(f"Max Accuracy:     {sw_df['accuracy'].max():.4f} (Vào giai đoạn: {sw_df.loc[sw_df['accuracy'].idxmax(), 'test_period']})")
print("="*80)
# Out:
# ================================================================================
# SLIDING WINDOW VALIDATION
# ================================================================================
# Generated 362 sliding windows.
# Train size: 3 years | Test size: 6 months
#
# Win 1: 1996-04-09 -> 1996-10-04 | Acc: 0.5476 (Thresh: 0.50) | Down Recall: 0.1778
# Win 2: 1996-10-07 -> 1997-04-07 | Acc: 0.3968 (Thresh: 0.51) | Down Recall: 1.0000
# Win 3: 1997-04-08 -> 1997-10-03 | Acc: 0.3333 (Thresh: 0.50) | Down Recall: 0.8000
# Win 4: 1997-10-06 -> 1998-04-06 | Acc: 0.5476 (Thresh: 0.72) | Down Recall: 0.7879
# Win 5: 1998-04-07 -> 1998-10-05 | Acc: 0.6111 (Thresh: 0.51) | Down Recall: 0.6462
# Win 6: 1998-10-06 -> 1999-04-07 | Acc: 0.7063 (Thresh: 0.51) | Down Recall: 0.3871
# Win 7: 1999-04-08 -> 1999-10-05 | Acc: 0.6190 (Thresh: 0.50) | Down Recall: 0.4262
# Win 8: 1999-10-06 -> 2000-04-04 | Acc: 0.6032 (Thresh: 0.52) | Down Recall: 0.7037
# Win 9: 2000-04-05 -> 2000-10-03 | Acc: 0.7222 (Thresh: 0.61) | Down Recall: 0.8873
# Win 10: 2000-10-04 -> 2001-04-04 | Acc: 0.6349 (Thresh: 0.54) | Down Recall: 0.8205
# Win 11: 2001-04-05 -> 2001-10-09 | Acc: 0.6270 (Thresh: 0.60) | Down Recall: 0.7945
# Win 12: 2001-10-10 -> 2002-04-11 | Acc: 0.5952 (Thresh: 0.50) | Down Recall: 0.8769
# Win 13: 2002-04-12 -> 2002-10-09 | Acc: 0.7698 (Thresh: 0.64) | Down Recall: 0.9884
# Win 14: 2002-10-10 -> 2003-04-10 | Acc: 0.5397 (Thresh: 0.50) | Down Recall: 0.9841
# Win 15: 2003-04-11 -> 2003-10-09 | Acc: 0.3095 (Thresh: 0.50) | Down Recall: 1.0000
# Win 16: 2003-10-10 -> 2004-04-12 | Acc: 0.6190 (Thresh: 0.50) | Down Recall: 0.1250
# Win 17: 2004-04-13 -> 2004-10-11 | Acc: 0.5952 (Thresh: 0.50) | Down Recall: 0.4000
# Win 18: 2004-10-12 -> 2005-04-12 | Acc: 0.5714 (Thresh: 0.50) | Down Recall: 0.1765
# Win 19: 2005-04-13 -> 2005-10-10 | Acc: 0.7222 (Thresh: 0.60) | Down Recall: 0.8462
# Win 20: 2005-10-11 -> 2006-04-11 | Acc: 0.5556 (Thresh: 0.52) | Down Recall: 0.7381
# Win 21: 2006-04-12 -> 2006-10-10 | Acc: 0.5000 (Thresh: 0.53) | Down Recall: 0.5789
# Win 22: 2006-10-11 -> 2007-04-13 | Acc: 0.7222 (Thresh: 0.50) | Down Recall: 0.7308
# Win 23: 2007-04-16 -> 2007-10-11 | Acc: 0.6508 (Thresh: 0.59) | Down Recall: 0.8298
# Win 24: 2007-10-12 -> 2008-04-14 | Acc: 0.6825 (Thresh: 0.50) | Down Recall: 0.7887
# Win 25: 2008-04-15 -> 2008-10-10 | Acc: 0.6508 (Thresh: 0.51) | Down Recall: 1.0000
# Win 26: 2008-10-13 -> 2009-04-14 | Acc: 0.5159 (Thresh: 0.50) | Down Recall: 0.4032
# Win 27: 2009-04-15 -> 2009-10-12 | Acc: 0.2937 (Thresh: 0.50) | Down Recall: 0.5000
# Win 28: 2009-10-13 -> 2010-04-14 | Acc: 0.6111 (Thresh: 0.53) | Down Recall: 0.6286
# Win 29: 2010-04-15 -> 2010-10-12 | Acc: 0.5794 (Thresh: 0.52) | Down Recall: 0.6429
# Win 30: 2010-10-13 -> 2011-04-12 | Acc: 0.6825 (Thresh: 0.51) | Down Recall: 0.5405
# Win 31: 2011-04-13 -> 2011-10-11 | Acc: 0.5397 (Thresh: 0.51) | Down Recall: 1.0000
# Win 32: 2011-10-12 -> 2012-04-12 | Acc: 0.6508 (Thresh: 0.56) | Down Recall: 0.7353
# Win 33: 2012-04-13 -> 2012-10-10 | Acc: 0.5238 (Thresh: 0.50) | Down Recall: 0.2075
# Win 34: 2012-10-11 -> 2013-04-16 | Acc: 0.6825 (Thresh: 0.50) | Down Recall: 0.6389
# Win 35: 2013-04-17 -> 2013-10-14 | Acc: 0.7460 (Thresh: 0.58) | Down Recall: 0.7391
# Win 36: 2013-10-15 -> 2014-04-15 | Acc: 0.6746 (Thresh: 0.51) | Down Recall: 0.4054
# Win 37: 2014-04-16 -> 2014-10-14 | Acc: 0.6587 (Thresh: 0.51) | Down Recall: 0.5556
# Win 38: 2014-10-15 -> 2015-04-16 | Acc: 0.7381 (Thresh: 0.51) | Down Recall: 0.5250
# Win 39: 2015-04-17 -> 2015-10-14 | Acc: 0.6587 (Thresh: 0.58) | Down Recall: 0.6812
# Win 40: 1999-05-20 -> 2015-12-31 | Acc: 0.5794 (Thresh: 0.50) | Down Recall: 0.5510
# Win 41: 1999-09-01 -> 2000-03-01 | Acc: 0.5714 (Thresh: 0.50) | Down Recall: 0.3103
# Win 42: 2000-03-02 -> 2000-08-29 | Acc: 0.5635 (Thresh: 0.53) | Down Recall: 0.5806
# Win 43: 2000-08-30 -> 2001-03-01 | Acc: 0.7698 (Thresh: 0.51) | Down Recall: 1.0000
# Win 44: 2001-03-02 -> 2001-08-29 | Acc: 0.6905 (Thresh: 0.50) | Down Recall: 1.0000
# Win 45: 2001-08-30 -> 2002-03-07 | Acc: 0.4524 (Thresh: 0.51) | Down Recall: 1.0000
# Win 46: 2002-03-08 -> 2002-09-05 | Acc: 0.7937 (Thresh: 0.60) | Down Recall: 1.0000
# Win 47: 2002-09-06 -> 2003-03-07 | Acc: 0.5159 (Thresh: 0.50) | Down Recall: 0.7333
# Win 48: 2003-03-10 -> 2003-09-05 | Acc: 0.7302 (Thresh: 0.50) | Down Recall: 0.5676
# Win 49: 2003-09-08 -> 2004-03-08 | Acc: 0.5159 (Thresh: 0.51) | Down Recall: 0.4762
# Win 50: 2004-03-09 -> 2004-09-07 | Acc: 0.5952 (Thresh: 0.50) | Down Recall: 0.2500
# Win 51: 2004-09-08 -> 2005-03-08 | Acc: 0.5476 (Thresh: 0.51) | Down Recall: 0.7647
# Win 52: 2005-03-09 -> 2005-09-06 | Acc: 0.6111 (Thresh: 0.56) | Down Recall: 1.0000
# Win 53: 2005-09-07 -> 2006-03-08 | Acc: 0.5000 (Thresh: 0.51) | Down Recall: 0.6842
# Win 54: 2006-03-09 -> 2006-09-06 | Acc: 0.6111 (Thresh: 0.60) | Down Recall: 0.8983
# Win 55: 2006-09-07 -> 2007-03-09 | Acc: 0.6746 (Thresh: 0.50) | Down Recall: 0.7619
# Win 56: 2007-03-12 -> 2007-09-07 | Acc: 0.5635 (Thresh: 0.50) | Down Recall: 0.7429
# Win 57: 2007-09-10 -> 2008-03-10 | Acc: 0.6746 (Thresh: 0.52) | Down Recall: 0.9851
# Win 58: 2008-03-11 -> 2008-09-08 | Acc: 0.4683 (Thresh: 0.50) | Down Recall: 0.8814
# Win 59: 2008-09-09 -> 2009-03-10 | Acc: 0.6032 (Thresh: 0.51) | Down Recall: 1.0000
# Win 60: 2009-03-11 -> 2009-09-08 | Acc: 0.4603 (Thresh: 0.52) | Down Recall: 0.6875
# Win 61: 2009-09-09 -> 2010-03-10 | Acc: 0.6984 (Thresh: 0.50) | Down Recall: 0.3590
# Win 62: 2010-03-11 -> 2010-09-08 | Acc: 0.4921 (Thresh: 0.50) | Down Recall: 0.7091
# Win 63: 2010-09-09 -> 2011-03-09 | Acc: 0.8016 (Thresh: 0.61) | Down Recall: 0.3429
# Win 64: 2011-03-10 -> 2011-09-07 | Acc: 0.5397 (Thresh: 0.50) | Down Recall: 0.3621
# Win 65: 2011-09-08 -> 2012-03-08 | Acc: 0.6349 (Thresh: 0.50) | Down Recall: 0.6667
# Win 66: 2012-03-09 -> 2012-09-06 | Acc: 0.6270 (Thresh: 0.53) | Down Recall: 0.6078
# Win 67: 2012-09-07 -> 2013-03-12 | Acc: 0.5159 (Thresh: 0.51) | Down Recall: 1.0000
# Win 68: 2013-03-13 -> 2013-09-10 | Acc: 0.5952 (Thresh: 0.50) | Down Recall: 0.3415
# Win 69: 2013-09-11 -> 2014-03-12 | Acc: 0.6349 (Thresh: 0.51) | Down Recall: 0.5000
# Win 70: 2014-03-13 -> 2014-09-10 | Acc: 0.5952 (Thresh: 0.50) | Down Recall: 0.5714
# Win 71: 2014-09-11 -> 2015-03-12 | Acc: 0.6270 (Thresh: 0.54) | Down Recall: 0.5472
# Win 72: 2015-03-13 -> 2015-09-10 | Acc: 0.6508 (Thresh: 0.53) | Down Recall: 0.5484
# Win 73: 2000-08-08 -> 2015-12-31 | Acc: 0.6429 (Thresh: 0.58) | Down Recall: 0.5846
# Win 74: 2000-10-16 -> 2001-04-17 | Acc: 0.6746 (Thresh: 0.50) | Down Recall: 0.6667
# Win 75: 2001-04-18 -> 2001-10-19 | Acc: 0.6032 (Thresh: 0.50) | Down Recall: 0.8939
# Win 76: 2001-10-22 -> 2002-04-23 | Acc: 0.4762 (Thresh: 0.50) | Down Recall: 0.9250
# Win 77: 2002-04-24 -> 2002-10-21 | Acc: 0.7937 (Thresh: 0.62) | Down Recall: 0.8111
# Win 78: 2002-10-22 -> 2003-04-23 | Acc: 0.6111 (Thresh: 0.50) | Down Recall: 0.6610
# Win 79: 2003-04-24 -> 2003-10-21 | Acc: 0.3730 (Thresh: 0.51) | Down Recall: 0.9286
# Win 80: 2003-10-22 -> 2004-04-22 | Acc: 0.5952 (Thresh: 0.50) | Down Recall: 0.5357
# Win 81: 2004-04-23 -> 2004-10-21 | Acc: 0.6111 (Thresh: 0.56) | Down Recall: 0.6271
# Win 82: 2004-10-22 -> 2005-04-22 | Acc: 0.4762 (Thresh: 0.51) | Down Recall: 0.6481
# Win 83: 2005-04-25 -> 2005-10-20 | Acc: 0.6587 (Thresh: 0.52) | Down Recall: 0.4762
# Win 84: 2005-10-21 -> 2006-04-24 | Acc: 0.5794 (Thresh: 0.50) | Down Recall: 0.4000
# Win 85: 2006-04-25 -> 2006-10-20 | Acc: 0.6984 (Thresh: 0.57) | Down Recall: 0.4808
# Win 86: 2006-10-23 -> 2007-04-25 | Acc: 0.7460 (Thresh: 0.62) | Down Recall: 0.5789
# Win 87: 2007-04-26 -> 2007-10-23 | Acc: 0.5238 (Thresh: 0.52) | Down Recall: 0.4828
# Win 88: 2007-10-24 -> 2008-04-24 | Acc: 0.6905 (Thresh: 0.64) | Down Recall: 0.9062
# Win 89: 2008-04-25 -> 2008-10-22 | Acc: 0.5873 (Thresh: 0.51) | Down Recall: 1.0000
# Win 90: 2008-10-23 -> 2009-04-24 | Acc: 0.6746 (Thresh: 0.57) | Down Recall: 0.6852
# Win 91: 2009-04-27 -> 2009-10-22 | Acc: 0.4603 (Thresh: 0.50) | Down Recall: 0.4615
# Win 92: 2009-10-23 -> 2010-04-26 | Acc: 0.5397 (Thresh: 0.50) | Down Recall: 0.8276
# Win 93: 2010-04-27 -> 2010-10-22 | Acc: 0.5952 (Thresh: 0.50) | Down Recall: 0.4737
# Win 94: 2010-10-25 -> 2011-04-25 | Acc: 0.5635 (Thresh: 0.50) | Down Recall: 0.3953
# Win 95: 2011-04-26 -> 2011-10-21 | Acc: 0.6429 (Thresh: 0.52) | Down Recall: 0.9265
# Win 96: 2011-10-24 -> 2012-04-24 | Acc: 0.5635 (Thresh: 0.50) | Down Recall: 0.4792
# Win 97: 2012-04-25 -> 2012-10-22 | Acc: 0.5397 (Thresh: 0.51) | Down Recall: 1.0000
# Win 98: 2012-10-23 -> 2013-04-26 | Acc: 0.6984 (Thresh: 0.50) | Down Recall: 0.5789
# Win 99: 2013-04-29 -> 2013-10-24 | Acc: 0.6667 (Thresh: 0.50) | Down Recall: 0.5417
# Win 100: 2013-10-25 -> 2014-04-28 | Acc: 0.6111 (Thresh: 0.55) | Down Recall: 0.7241
# Win 101: 2014-04-29 -> 2014-10-24 | Acc: 0.6587 (Thresh: 0.70) | Down Recall: 0.9344
# Win 102: 2014-10-27 -> 2015-04-28 | Acc: 0.5952 (Thresh: 0.50) | Down Recall: 0.6327
# Win 103: 2015-04-29 -> 2015-10-26 | Acc: 0.7063 (Thresh: 0.55) | Down Recall: 0.5833
# Win 104: 2002-10-09 -> 2015-12-31 | Acc: 0.5794 (Thresh: 0.50) | Down Recall: 0.5283
# Win 105: 2003-02-04 -> 2003-08-04 | Acc: 0.5079 (Thresh: 0.51) | Down Recall: 1.0000
# Win 106: 2003-08-05 -> 2004-02-03 | Acc: 0.6746 (Thresh: 0.55) | Down Recall: 0.8444
# Win 107: 2004-02-04 -> 2004-08-04 | Acc: 0.6905 (Thresh: 0.57) | Down Recall: 0.6275
# Win 108: 2004-08-05 -> 2005-02-02 | Acc: 0.5952 (Thresh: 0.50) | Down Recall: 0.3243
# Win 109: 2005-02-03 -> 2005-08-03 | Acc: 0.6270 (Thresh: 0.67) | Down Recall: 0.7500
# Win 110: 2005-08-04 -> 2006-02-02 | Acc: 0.5556 (Thresh: 0.51) | Down Recall: 1.0000
# Win 111: 2006-02-03 -> 2006-08-03 | Acc: 0.5873 (Thresh: 0.50) | Down Recall: 0.6667
# Win 112: 2006-08-04 -> 2007-02-05 | Acc: 0.6429 (Thresh: 0.54) | Down Recall: 0.2745
# Win 113: 2007-02-06 -> 2007-08-06 | Acc: 0.5873 (Thresh: 0.51) | Down Recall: 0.7167
# Win 114: 2007-08-07 -> 2008-02-05 | Acc: 0.5556 (Thresh: 0.50) | Down Recall: 0.7727
# Win 115: 2008-02-06 -> 2008-08-05 | Acc: 0.6111 (Thresh: 0.53) | Down Recall: 0.3750
# Win 116: 2008-08-06 -> 2009-02-04 | Acc: 0.6032 (Thresh: 0.50) | Down Recall: 0.6667
# Win 117: 2009-02-05 -> 2009-08-05 | Acc: 0.6111 (Thresh: 0.51) | Down Recall: 1.0000
# Win 118: 2009-08-06 -> 2010-02-04 | Acc: 0.5556 (Thresh: 0.52) | Down Recall: 0.8382
# Win 119: 2010-02-05 -> 2010-08-05 | Acc: 0.4841 (Thresh: 0.50) | Down Recall: 0.4634
# Win 120: 2010-08-06 -> 2011-02-03 | Acc: 0.7143 (Thresh: 0.58) | Down Recall: 1.0000
# Win 121: 2011-02-04 -> 2011-08-04 | Acc: 0.5397 (Thresh: 0.50) | Down Recall: 0.5000
# Win 122: 2011-08-05 -> 2012-02-03 | Acc: 0.5556 (Thresh: 0.52) | Down Recall: 0.8302
# Win 123: 2012-02-06 -> 2012-08-03 | Acc: 0.4444 (Thresh: 0.50) | Down Recall: 0.8974
# Win 124: 2012-08-06 -> 2013-02-06 | Acc: 0.6032 (Thresh: 0.51) | Down Recall: 0.8816
# Win 125: 2013-02-07 -> 2013-08-07 | Acc: 0.6508 (Thresh: 0.59) | Down Recall: 0.9878
# Win 126: 2013-08-08 -> 2014-02-06 | Acc: 0.5476 (Thresh: 0.53) | Down Recall: 0.7903
# Win 127: 2014-02-07 -> 2014-08-07 | Acc: 0.6508 (Thresh: 0.51) | Down Recall: 0.6000
# Win 128: 2014-08-08 -> 2015-02-06 | Acc: 0.5159 (Thresh: 0.50) | Down Recall: 0.4318
# Win 129: 2015-02-09 -> 2015-08-07 | Acc: 0.5635 (Thresh: 0.51) | Down Recall: 0.6935
# Win 130: 2005-02-01 -> 2015-12-31 | Acc: 0.5476 (Thresh: 0.54) | Down Recall: 0.6538
# Win 131: 2005-03-09 -> 2005-09-06 | Acc: 0.6825 (Thresh: 0.56) | Down Recall: 0.3393
# Win 132: 2005-09-07 -> 2006-03-08 | Acc: 0.4762 (Thresh: 0.51) | Down Recall: 0.8298
# Win 133: 2006-03-09 -> 2006-09-06 | Acc: 0.5952 (Thresh: 0.50) | Down Recall: 0.8136
# Win 134: 2006-09-07 -> 2007-03-09 | Acc: 0.6032 (Thresh: 0.50) | Down Recall: 0.3125
# Win 135: 2007-03-12 -> 2007-09-07 | Acc: 0.6587 (Thresh: 0.54) | Down Recall: 0.5968
# Win 136: 2007-09-10 -> 2008-03-10 | Acc: 0.3333 (Thresh: 0.50) | Down Recall: 1.0000
# Win 137: 2008-03-11 -> 2008-09-08 | Acc: 0.5952 (Thresh: 0.52) | Down Recall: 1.0000
# Win 138: 2008-09-09 -> 2009-03-10 | Acc: 0.5556 (Thresh: 0.50) | Down Recall: 0.7843
# Win 139: 2009-03-11 -> 2009-09-08 | Acc: 0.6111 (Thresh: 0.51) | Down Recall: 0.3600
# Win 140: 2009-09-09 -> 2010-03-10 | Acc: 0.5794 (Thresh: 0.50) | Down Recall: 0.3091
# Win 141: 2010-03-11 -> 2010-09-08 | Acc: 0.6905 (Thresh: 0.52) | Down Recall: 0.5263
# Win 142: 2010-09-09 -> 2011-03-09 | Acc: 0.7460 (Thresh: 0.57) | Down Recall: 0.7736
# Win 143: 2011-03-10 -> 2011-09-07 | Acc: 0.6032 (Thresh: 0.50) | Down Recall: 0.4286
# Win 144: 2011-09-08 -> 2012-03-08 | Acc: 0.7937 (Thresh: 0.69) | Down Recall: 0.9516
# Win 145: 2012-03-09 -> 2012-09-06 | Acc: 0.6508 (Thresh: 0.51) | Down Recall: 0.3148
# Win 146: 2012-09-07 -> 2013-03-12 | Acc: 0.5952 (Thresh: 0.51) | Down Recall: 1.0000
# Win 147: 2013-03-13 -> 2013-09-10 | Acc: 0.6984 (Thresh: 0.51) | Down Recall: 0.6027
# Win 148: 2013-09-11 -> 2014-03-12 | Acc: 0.5873 (Thresh: 0.50) | Down Recall: 0.2881
# Win 149: 2014-03-13 -> 2014-09-10 | Acc: 0.6905 (Thresh: 0.55) | Down Recall: 0.7237
# Win 150: 2014-09-11 -> 2015-03-12 | Acc: 0.6429 (Thresh: 0.52) | Down Recall: 0.9559
# Win 151: 2015-03-13 -> 2015-09-10 | Acc: 0.6508 (Thresh: 0.60) | Down Recall: 0.8310
# Win 152: 1999-04-06 -> 2015-12-31 | Acc: 0.6111 (Thresh: 0.59) | Down Recall: 0.9867
# Win 153: 1999-06-14 -> 1999-12-09 | Acc: 0.4286 (Thresh: 0.50) | Down Recall: 1.0000
# Win 154: 1999-12-10 -> 2000-06-09 | Acc: 0.6667 (Thresh: 0.51) | Down Recall: 0.7111
# Win 155: 2000-06-12 -> 2000-12-07 | Acc: 0.6349 (Thresh: 0.52) | Down Recall: 0.6522
# Win 156: 2000-12-08 -> 2001-06-11 | Acc: 0.5397 (Thresh: 0.53) | Down Recall: 0.8537
# Win 157: 2001-06-12 -> 2001-12-13 | Acc: 0.4444 (Thresh: 0.50) | Down Recall: 0.4118
# Win 158: 2001-12-14 -> 2002-06-17 | Acc: 0.7778 (Thresh: 0.51) | Down Recall: 0.9794
# Win 159: 2002-06-18 -> 2002-12-13 | Acc: 0.6508 (Thresh: 0.62) | Down Recall: 0.8514
# Win 160: 2002-12-16 -> 2003-06-17 | Acc: 0.5476 (Thresh: 0.51) | Down Recall: 0.8621
# Win 161: 2003-06-18 -> 2003-12-15 | Acc: 0.6825 (Thresh: 0.52) | Down Recall: 0.8966
# Win 162: 2003-12-16 -> 2004-06-17 | Acc: 0.6111 (Thresh: 0.51) | Down Recall: 0.4085
# Win 163: 2004-06-18 -> 2004-12-15 | Acc: 0.6111 (Thresh: 0.50) | Down Recall: 0.0208
# Win 164: 2004-12-16 -> 2005-06-16 | Acc: 0.5317 (Thresh: 0.51) | Down Recall: 1.0000
# Win 165: 2005-06-17 -> 2005-12-14 | Acc: 0.2778 (Thresh: 0.50) | Down Recall: 1.0000
# Win 166: 2005-12-15 -> 2006-06-16 | Acc: 0.6190 (Thresh: 0.50) | Down Recall: 0.8113
# Win 167: 2006-06-19 -> 2006-12-14 | Acc: 0.5794 (Thresh: 0.50) | Down Recall: 0.7931
# Win 168: 2006-12-15 -> 2007-06-19 | Acc: 0.5159 (Thresh: 0.50) | Down Recall: 0.3462
# Win 169: 2007-06-20 -> 2007-12-17 | Acc: 0.5794 (Thresh: 0.50) | Down Recall: 0.0962
# Win 170: 2007-12-18 -> 2008-06-18 | Acc: 0.6190 (Thresh: 0.57) | Down Recall: 1.0000
# Win 171: 2008-06-19 -> 2008-12-16 | Acc: 0.6190 (Thresh: 0.53) | Down Recall: 0.8800
# Win 172: 2008-12-17 -> 2009-06-18 | Acc: 0.5952 (Thresh: 0.50) | Down Recall: 0.0217
# Win 173: 2009-06-19 -> 2009-12-16 | Acc: 0.5952 (Thresh: 0.51) | Down Recall: 0.4717
# Win 174: 2009-12-17 -> 2010-06-18 | Acc: 0.6746 (Thresh: 0.52) | Down Recall: 1.0000
# Win 175: 2010-06-21 -> 2010-12-16 | Acc: 0.4286 (Thresh: 0.50) | Down Recall: 0.4872
# Win 176: 2010-12-17 -> 2011-06-17 | Acc: 0.6825 (Thresh: 0.50) | Down Recall: 0.8030
# Win 177: 2011-06-20 -> 2011-12-15 | Acc: 0.5952 (Thresh: 0.50) | Down Recall: 0.7887
# Win 178: 2011-12-16 -> 2012-06-18 | Acc: 0.6111 (Thresh: 0.56) | Down Recall: 0.9855
# Win 179: 2012-06-19 -> 2012-12-18 | Acc: 0.7063 (Thresh: 0.66) | Down Recall: 0.8955
# Win 180: 2012-12-19 -> 2013-06-20 | Acc: 0.4286 (Thresh: 0.50) | Down Recall: 0.7800
# Win 181: 2013-06-21 -> 2013-12-18 | Acc: 0.5000 (Thresh: 0.50) | Down Recall: 0.4231
# Win 182: 2013-12-19 -> 2014-06-20 | Acc: 0.6190 (Thresh: 0.56) | Down Recall: 0.9643
# Win 183: 2014-06-23 -> 2014-12-18 | Acc: 0.5635 (Thresh: 0.51) | Down Recall: 0.8448
# Win 184: 2014-12-19 -> 2015-06-22 | Acc: 0.5476 (Thresh: 0.50) | Down Recall: 0.3485
# Win 185: 2015-06-23 -> 2015-12-18 | Acc: 0.5873 (Thresh: 0.50) | Down Recall: 0.1765
# Win 186: 1990-03-14 -> 2015-12-31 | Acc: 0.5794 (Thresh: 0.51) | Down Recall: 1.0000
# Win 187: 1990-08-30 -> 1991-02-28 | Acc: 0.6111 (Thresh: 0.55) | Down Recall: 0.9859
# Win 188: 1991-03-01 -> 1991-08-28 | Acc: 0.6667 (Thresh: 0.51) | Down Recall: 0.3509
# Win 189: 1991-08-29 -> 1992-02-27 | Acc: 0.6190 (Thresh: 0.50) | Down Recall: 0.7460
# Win 190: 1992-02-28 -> 1992-08-26 | Acc: 0.5794 (Thresh: 0.51) | Down Recall: 1.0000
# Win 191: 1992-08-27 -> 1993-02-25 | Acc: 0.4206 (Thresh: 0.50) | Down Recall: 0.9487
# Win 192: 1993-02-26 -> 1993-08-25 | Acc: 0.5159 (Thresh: 0.51) | Down Recall: 0.6094
# Win 193: 1993-08-26 -> 1994-02-23 | Acc: 0.6032 (Thresh: 0.51) | Down Recall: 0.6308
# Win 194: 1994-02-24 -> 1994-08-24 | Acc: 0.5317 (Thresh: 0.51) | Down Recall: 1.0000
# Win 195: 1994-08-25 -> 1995-02-23 | Acc: 0.6032 (Thresh: 0.51) | Down Recall: 0.4375
# Win 196: 1995-02-24 -> 1995-08-23 | Acc: 0.5556 (Thresh: 0.50) | Down Recall: 0.4583
# Win 197: 1995-08-24 -> 1996-02-22 | Acc: 0.5714 (Thresh: 0.51) | Down Recall: 0.5455
# Win 198: 1996-02-23 -> 1996-08-21 | Acc: 0.5476 (Thresh: 0.54) | Down Recall: 0.4138
# Win 199: 1996-08-22 -> 1997-02-20 | Acc: 0.6032 (Thresh: 0.50) | Down Recall: 0.4800
# Win 200: 1997-02-21 -> 1997-08-20 | Acc: 0.6111 (Thresh: 0.50) | Down Recall: 0.1176
# Win 201: 1997-08-21 -> 1998-02-20 | Acc: 0.6825 (Thresh: 0.64) | Down Recall: 0.7963
# Win 202: 1998-02-23 -> 1998-08-20 | Acc: 0.6270 (Thresh: 0.52) | Down Recall: 0.9194
# Win 203: 1998-08-21 -> 1999-02-22 | Acc: 0.3492 (Thresh: 0.50) | Down Recall: 1.0000
# Win 204: 1999-02-23 -> 1999-08-20 | Acc: 0.5317 (Thresh: 0.51) | Down Recall: 1.0000
# Win 205: 1999-08-23 -> 2000-02-18 | Acc: 0.6349 (Thresh: 0.55) | Down Recall: 1.0000
# Win 206: 2000-02-22 -> 2000-08-18 | Acc: 0.5794 (Thresh: 0.52) | Down Recall: 0.8966
# Win 207: 2000-08-21 -> 2001-02-20 | Acc: 0.5635 (Thresh: 0.51) | Down Recall: 0.8906
# Win 208: 2001-02-21 -> 2001-08-20 | Acc: 0.5873 (Thresh: 0.52) | Down Recall: 1.0000
# Win 209: 2001-08-21 -> 2002-02-26 | Acc: 0.5714 (Thresh: 0.55) | Down Recall: 0.8088
# Win 210: 2002-02-27 -> 2002-08-26 | Acc: 0.5635 (Thresh: 0.51) | Down Recall: 0.8261
# Win 211: 2002-08-27 -> 2003-02-26 | Acc: 0.6190 (Thresh: 0.51) | Down Recall: 0.7429
# Win 212: 2003-02-27 -> 2003-08-26 | Acc: 0.3810 (Thresh: 0.50) | Down Recall: 0.3333
# Win 213: 2003-08-27 -> 2004-02-26 | Acc: 0.6905 (Thresh: 0.50) | Down Recall: 0.0000
# Win 214: 2004-02-27 -> 2004-08-26 | Acc: 0.6032 (Thresh: 0.51) | Down Recall: 0.4167
# Win 215: 2004-08-27 -> 2005-02-25 | Acc: 0.7143 (Thresh: 0.56) | Down Recall: 0.7042
# Win 216: 2005-02-28 -> 2005-08-25 | Acc: 0.6111 (Thresh: 0.58) | Down Recall: 0.8714
# Win 217: 2005-08-26 -> 2006-02-27 | Acc: 0.4206 (Thresh: 0.50) | Down Recall: 0.5667
# Win 218: 2006-02-28 -> 2006-08-25 | Acc: 0.3492 (Thresh: 0.51) | Down Recall: 1.0000
# Win 219: 2006-08-28 -> 2007-02-28 | Acc: 0.6825 (Thresh: 0.50) | Down Recall: 0.5250
# Win 220: 2007-03-01 -> 2007-08-28 | Acc: 0.5794 (Thresh: 0.51) | Down Recall: 1.0000
# Win 221: 2007-08-29 -> 2008-02-28 | Acc: 0.7143 (Thresh: 0.54) | Down Recall: 0.8701
# Win 222: 2008-02-29 -> 2008-08-27 | Acc: 0.6984 (Thresh: 0.57) | Down Recall: 0.9853
# Win 223: 2008-08-28 -> 2009-02-27 | Acc: 0.6508 (Thresh: 0.51) | Down Recall: 1.0000
# Win 224: 2009-03-02 -> 2009-08-27 | Acc: 0.4048 (Thresh: 0.50) | Down Recall: 0.9487
# Win 225: 2009-08-28 -> 2010-03-01 | Acc: 0.5238 (Thresh: 0.51) | Down Recall: 0.9661
# Win 226: 2010-03-02 -> 2010-08-27 | Acc: 0.6190 (Thresh: 0.50) | Down Recall: 0.6618
# Win 227: 2010-08-30 -> 2011-02-28 | Acc: 0.6508 (Thresh: 0.50) | Down Recall: 0.8837
# Win 228: 2011-03-01 -> 2011-08-26 | Acc: 0.5714 (Thresh: 0.51) | Down Recall: 1.0000
# Win 229: 2011-08-29 -> 2012-02-28 | Acc: 0.6508 (Thresh: 0.52) | Down Recall: 0.6154
# Win 230: 2012-02-29 -> 2012-08-27 | Acc: 0.5476 (Thresh: 0.50) | Down Recall: 0.4828
# Win 231: 2012-08-28 -> 2013-03-01 | Acc: 0.6508 (Thresh: 0.52) | Down Recall: 0.3571
# Win 232: 2013-03-04 -> 2013-08-29 | Acc: 0.5317 (Thresh: 0.50) | Down Recall: 0.0000
# Win 233: 2013-08-30 -> 2014-03-03 | Acc: 0.5794 (Thresh: 0.50) | Down Recall: 0.2500
# Win 234: 2014-03-04 -> 2014-08-29 | Acc: 0.6349 (Thresh: 0.50) | Down Recall: 0.5217
# Win 235: 2014-09-02 -> 2015-03-03 | Acc: 0.6587 (Thresh: 0.50) | Down Recall: 0.7627
# Win 236: 2015-03-04 -> 2015-08-31 | Acc: 0.4683 (Thresh: 0.51) | Down Recall: 1.0000
# Win 237: 1990-03-14 -> 2015-12-31 | Acc: 0.5714 (Thresh: 0.54) | Down Recall: 0.9825
# Win 238: 1990-05-11 -> 1990-11-07 | Acc: 0.4683 (Thresh: 0.50) | Down Recall: 1.0000
# Win 239: 1990-11-08 -> 1991-05-09 | Acc: 0.4683 (Thresh: 0.50) | Down Recall: 0.9756
# Win 240: 1991-05-10 -> 1991-11-06 | Acc: 0.5873 (Thresh: 0.51) | Down Recall: 0.3889
# Win 241: 1991-11-07 -> 1992-05-07 | Acc: 0.6349 (Thresh: 0.51) | Down Recall: 0.7167
# Win 242: 1992-05-08 -> 1992-11-04 | Acc: 0.5873 (Thresh: 0.50) | Down Recall: 0.7667
# Win 243: 1992-11-05 -> 1993-05-06 | Acc: 0.5397 (Thresh: 0.51) | Down Recall: 0.6304
# Win 244: 1993-05-07 -> 1993-11-03 | Acc: 0.5873 (Thresh: 0.50) | Down Recall: 0.3667
# Win 245: 1993-11-04 -> 1994-05-05 | Acc: 0.6270 (Thresh: 0.58) | Down Recall: 0.6727
# Win 246: 1994-05-06 -> 1994-11-02 | Acc: 0.5794 (Thresh: 0.59) | Down Recall: 0.9508
# Win 247: 1994-11-03 -> 1995-05-04 | Acc: 0.6270 (Thresh: 0.50) | Down Recall: 0.4286
# Win 248: 1995-05-05 -> 1995-11-01 | Acc: 0.4841 (Thresh: 0.51) | Down Recall: 0.8125
# Win 249: 1995-11-02 -> 1996-05-02 | Acc: 0.4206 (Thresh: 0.50) | Down Recall: 1.0000
# Win 250: 1996-05-03 -> 1996-10-30 | Acc: 0.4286 (Thresh: 0.50) | Down Recall: 0.5111
# Win 251: 1996-10-31 -> 1997-05-01 | Acc: 0.5714 (Thresh: 0.50) | Down Recall: 0.6333
# Win 252: 1997-05-02 -> 1997-10-29 | Acc: 0.5794 (Thresh: 0.51) | Down Recall: 0.6415
# Win 253: 1997-10-30 -> 1998-05-01 | Acc: 0.5794 (Thresh: 0.50) | Down Recall: 0.6444
# Win 254: 1998-05-04 -> 1998-10-29 | Acc: 0.5873 (Thresh: 0.52) | Down Recall: 0.6212
# Win 255: 1998-10-30 -> 1999-05-03 | Acc: 0.6270 (Thresh: 0.60) | Down Recall: 0.9259
# Win 256: 1999-05-04 -> 1999-10-29 | Acc: 0.6190 (Thresh: 0.51) | Down Recall: 0.8429
# Win 257: 1999-11-01 -> 2000-05-01 | Acc: 0.6746 (Thresh: 0.50) | Down Recall: 0.5472
# Win 258: 2000-05-02 -> 2000-10-27 | Acc: 0.5476 (Thresh: 0.50) | Down Recall: 0.7708
# Win 259: 2000-10-30 -> 2001-05-01 | Acc: 0.6667 (Thresh: 0.50) | Down Recall: 0.5469
# Win 260: 2001-05-02 -> 2001-11-02 | Acc: 0.6984 (Thresh: 0.51) | Down Recall: 1.0000
# Win 261: 2001-11-05 -> 2002-05-07 | Acc: 0.5873 (Thresh: 0.51) | Down Recall: 0.7015
# Win 262: 2002-05-08 -> 2002-11-04 | Acc: 0.7063 (Thresh: 0.54) | Down Recall: 0.7647
# Win 263: 2002-11-05 -> 2003-05-07 | Acc: 0.6746 (Thresh: 0.51) | Down Recall: 0.5882
# Win 264: 2003-05-08 -> 2003-11-04 | Acc: 0.5238 (Thresh: 0.50) | Down Recall: 0.9483
# Win 265: 2003-11-05 -> 2004-05-06 | Acc: 0.5079 (Thresh: 0.50) | Down Recall: 1.0000
# Win 266: 2004-05-07 -> 2004-11-04 | Acc: 0.6270 (Thresh: 0.50) | Down Recall: 0.6207
# Win 267: 2004-11-05 -> 2005-05-06 | Acc: 0.7540 (Thresh: 0.65) | Down Recall: 0.9206
# Win 268: 2005-05-09 -> 2005-11-03 | Acc: 0.7381 (Thresh: 0.50) | Down Recall: 0.9434
# Win 269: 2005-11-04 -> 2006-05-08 | Acc: 0.6905 (Thresh: 0.50) | Down Recall: 0.5000
# Win 270: 2006-05-09 -> 2006-11-03 | Acc: 0.4206 (Thresh: 0.50) | Down Recall: 0.9250
# Win 271: 2006-11-06 -> 2007-05-09 | Acc: 0.5952 (Thresh: 0.52) | Down Recall: 0.5854
# Win 272: 2007-05-10 -> 2007-11-06 | Acc: 0.5476 (Thresh: 0.50) | Down Recall: 0.8966
# Win 273: 2007-11-07 -> 2008-05-08 | Acc: 0.6825 (Thresh: 0.56) | Down Recall: 0.6731
# Win 274: 2008-05-09 -> 2008-11-05 | Acc: 0.6825 (Thresh: 0.50) | Down Recall: 0.6220
# Win 275: 2008-11-06 -> 2009-05-08 | Acc: 0.5159 (Thresh: 0.52) | Down Recall: 1.0000
# Win 276: 2009-05-11 -> 2009-11-05 | Acc: 0.5079 (Thresh: 0.51) | Down Recall: 1.0000
# Win 277: 2009-11-06 -> 2010-05-10 | Acc: 0.5952 (Thresh: 0.51) | Down Recall: 0.3281
# Win 278: 2010-05-11 -> 2010-11-05 | Acc: 0.5079 (Thresh: 0.50) | Down Recall: 0.3333
# Win 279: 2010-11-08 -> 2011-05-09 | Acc: 0.6190 (Thresh: 0.50) | Down Recall: 0.9459
# Win 280: 2011-05-10 -> 2011-11-04 | Acc: 0.5238 (Thresh: 0.50) | Down Recall: 0.7460
# Win 281: 2011-11-07 -> 2012-05-08 | Acc: 0.4444 (Thresh: 0.51) | Down Recall: 1.0000
# Win 282: 2012-05-09 -> 2012-11-07 | Acc: 0.5079 (Thresh: 0.51) | Down Recall: 0.7593
# Win 283: 2012-11-08 -> 2013-05-10 | Acc: 0.3889 (Thresh: 0.51) | Down Recall: 1.0000
# Win 284: 2013-05-13 -> 2013-11-07 | Acc: 0.6111 (Thresh: 0.50) | Down Recall: 0.8750
# Win 285: 2013-11-08 -> 2014-05-12 | Acc: 0.4524 (Thresh: 0.50) | Down Recall: 0.7647
# Win 286: 2014-05-13 -> 2014-11-07 | Acc: 0.5079 (Thresh: 0.51) | Down Recall: 1.0000
# Win 287: 2014-11-10 -> 2015-05-12 | Acc: 0.5952 (Thresh: 0.51) | Down Recall: 1.0000
# Win 288: 2015-05-13 -> 2015-11-09 | Acc: 0.6032 (Thresh: 0.60) | Down Recall: 0.9726
# Win 289: 1990-03-14 -> 2015-12-31 | Acc: 0.7778 (Thresh: 0.51) | Down Recall: 0.7391
# Win 290: 1990-07-23 -> 1991-01-18 | Acc: 0.6905 (Thresh: 0.51) | Down Recall: 0.5932
# Win 291: 1991-01-21 -> 1991-07-19 | Acc: 0.3968 (Thresh: 0.51) | Down Recall: 1.0000
# Win 292: 1991-07-22 -> 1992-01-17 | Acc: 0.5079 (Thresh: 0.50) | Down Recall: 0.2963
# Win 293: 1992-01-20 -> 1992-07-17 | Acc: 0.6349 (Thresh: 0.55) | Down Recall: 0.9067
# Win 294: 1992-07-20 -> 1993-01-15 | Acc: 0.5159 (Thresh: 0.50) | Down Recall: 0.8571
# Win 295: 1993-01-18 -> 1993-07-16 | Acc: 0.6746 (Thresh: 0.57) | Down Recall: 0.7808
# Win 296: 1993-07-19 -> 1994-01-13 | Acc: 0.4048 (Thresh: 0.51) | Down Recall: 1.0000
# Win 297: 1994-01-14 -> 1994-07-15 | Acc: 0.5317 (Thresh: 0.51) | Down Recall: 1.0000
# Win 298: 1994-07-18 -> 1995-01-13 | Acc: 0.6270 (Thresh: 0.50) | Down Recall: 0.5652
# Win 299: 1995-01-16 -> 1995-07-14 | Acc: 0.5476 (Thresh: 0.52) | Down Recall: 0.6429
# Win 300: 1995-07-17 -> 1996-01-12 | Acc: 0.5397 (Thresh: 0.50) | Down Recall: 0.6923
# Win 301: 1996-01-15 -> 1996-07-12 | Acc: 0.5476 (Thresh: 0.50) | Down Recall: 0.4107
# Win 302: 1996-07-15 -> 1997-01-10 | Acc: 0.6587 (Thresh: 0.51) | Down Recall: 0.4681
# Win 303: 1997-01-13 -> 1997-07-11 | Acc: 0.6587 (Thresh: 0.50) | Down Recall: 0.8167
# Win 304: 1997-07-14 -> 1998-01-09 | Acc: 0.5159 (Thresh: 0.51) | Down Recall: 0.7736
# Win 305: 1998-01-12 -> 1998-07-13 | Acc: 0.4286 (Thresh: 0.50) | Down Recall: 0.9535
# Win 306: 1998-07-14 -> 1999-01-11 | Acc: 0.6270 (Thresh: 0.50) | Down Recall: 0.7719
# Win 307: 1999-01-12 -> 1999-07-13 | Acc: 0.5000 (Thresh: 0.50) | Down Recall: 0.4634
# Win 308: 1999-07-14 -> 2000-01-10 | Acc: 0.6270 (Thresh: 0.55) | Down Recall: 0.8406
# Win 309: 2000-01-11 -> 2000-07-11 | Acc: 0.4762 (Thresh: 0.51) | Down Recall: 1.0000
# Win 310: 2000-07-12 -> 2001-01-09 | Acc: 0.5873 (Thresh: 0.50) | Down Recall: 0.4194
# Win 311: 2001-01-10 -> 2001-07-11 | Acc: 0.5873 (Thresh: 0.50) | Down Recall: 0.6000
# Win 312: 2001-07-12 -> 2002-01-15 | Acc: 0.7619 (Thresh: 0.50) | Down Recall: 0.5833
# Win 313: 2002-01-16 -> 2002-07-17 | Acc: 0.6429 (Thresh: 0.51) | Down Recall: 0.9221
# Win 314: 2002-07-18 -> 2003-01-15 | Acc: 0.5476 (Thresh: 0.51) | Down Recall: 0.5645
# Win 315: 2003-01-16 -> 2003-07-17 | Acc: 0.5714 (Thresh: 0.51) | Down Recall: 0.9857
# Win 316: 2003-07-18 -> 2004-01-15 | Acc: 0.4286 (Thresh: 0.50) | Down Recall: 0.8679
# Win 317: 2004-01-16 -> 2004-07-19 | Acc: 0.6190 (Thresh: 0.55) | Down Recall: 0.2308
# Win 318: 2004-07-20 -> 2005-01-14 | Acc: 0.6746 (Thresh: 0.56) | Down Recall: 0.5682
# Win 319: 2005-01-18 -> 2005-07-18 | Acc: 0.5397 (Thresh: 0.51) | Down Recall: 1.0000
# Win 320: 2005-07-19 -> 2006-01-17 | Acc: 0.5873 (Thresh: 0.65) | Down Recall: 0.9853
# Win 321: 2006-01-18 -> 2006-07-18 | Acc: 0.4206 (Thresh: 0.50) | Down Recall: 0.8261
# Win 322: 2006-07-19 -> 2007-01-18 | Acc: 0.5317 (Thresh: 0.50) | Down Recall: 0.6667
# Win 323: 2007-01-19 -> 2007-07-19 | Acc: 0.7063 (Thresh: 0.54) | Down Recall: 1.0000
# Win 324: 2007-07-20 -> 2008-01-17 | Acc: 0.5159 (Thresh: 0.52) | Down Recall: 0.9574
# Win 325: 2008-01-18 -> 2008-07-18 | Acc: 0.5079 (Thresh: 0.50) | Down Recall: 0.7143
# Win 326: 2008-07-21 -> 2009-01-16 | Acc: 0.5873 (Thresh: 0.60) | Down Recall: 1.0000
# Win 327: 2009-01-20 -> 2009-07-20 | Acc: 0.3730 (Thresh: 0.50) | Down Recall: 1.0000
# Win 328: 2009-07-21 -> 2010-01-19 | Acc: 0.5238 (Thresh: 0.51) | Down Recall: 0.5091
# Win 329: 2010-01-20 -> 2010-07-20 | Acc: 0.6270 (Thresh: 0.51) | Down Recall: 0.5397
# Win 330: 2010-07-21 -> 2011-01-18 | Acc: 0.5238 (Thresh: 0.50) | Down Recall: 0.2885
# Win 331: 2011-01-19 -> 2011-07-19 | Acc: 0.5794 (Thresh: 0.55) | Down Recall: 0.6042
# Win 332: 2011-07-20 -> 2012-01-18 | Acc: 0.5079 (Thresh: 0.50) | Down Recall: 0.7736
# Win 333: 2012-01-19 -> 2012-07-18 | Acc: 0.5556 (Thresh: 0.50) | Down Recall: 0.1400
# Win 334: 2012-07-19 -> 2013-01-18 | Acc: 0.5159 (Thresh: 0.51) | Down Recall: 0.5652
# Win 335: 2013-01-22 -> 2013-07-22 | Acc: 0.7063 (Thresh: 0.50) | Down Recall: 0.6667
# Win 336: 2013-07-23 -> 2014-01-21 | Acc: 0.6667 (Thresh: 0.66) | Down Recall: 0.8136
# Win 337: 2014-01-22 -> 2014-07-22 | Acc: 0.5159 (Thresh: 0.50) | Down Recall: 0.5938
# Win 338: 2014-07-23 -> 2015-01-21 | Acc: 0.6270 (Thresh: 0.67) | Down Recall: 0.9508
# Win 339: 2015-01-22 -> 2015-07-22 | Acc: 0.5635 (Thresh: 0.51) | Down Recall: 0.8333
# Win 340: 2004-12-09 -> 2015-12-31 | Acc: 0.5397 (Thresh: 0.50) | Down Recall: 0.5345
# Win 341: 2004-12-29 -> 2005-06-28 | Acc: 0.8413 (Thresh: 0.63) | Down Recall: 0.5476
# Win 342: 2005-06-29 -> 2005-12-27 | Acc: 0.5317 (Thresh: 0.50) | Down Recall: 0.5000
# Win 343: 2005-12-28 -> 2006-06-28 | Acc: 0.6587 (Thresh: 0.63) | Down Recall: 0.6522
# Win 344: 2006-06-29 -> 2006-12-27 | Acc: 0.5794 (Thresh: 0.52) | Down Recall: 0.4324
# Win 345: 2006-12-28 -> 2007-06-29 | Acc: 0.6429 (Thresh: 0.56) | Down Recall: 0.7143
# Win 346: 2007-07-02 -> 2007-12-28 | Acc: 0.6349 (Thresh: 0.53) | Down Recall: 0.8375
# Win 347: 2007-12-31 -> 2008-06-30 | Acc: 0.5635 (Thresh: 0.53) | Down Recall: 1.0000
# Win 348: 2008-07-01 -> 2008-12-29 | Acc: 0.5317 (Thresh: 0.51) | Down Recall: 1.0000
# Win 349: 2008-12-30 -> 2009-06-30 | Acc: 0.5476 (Thresh: 0.51) | Down Recall: 1.0000
# Win 350: 2009-07-01 -> 2009-12-29 | Acc: 0.5079 (Thresh: 0.51) | Down Recall: 0.8611
# Win 351: 2009-12-30 -> 2010-06-30 | Acc: 0.5159 (Thresh: 0.51) | Down Recall: 0.6066
# Win 352: 2010-07-01 -> 2010-12-29 | Acc: 0.4524 (Thresh: 0.50) | Down Recall: 0.7273
# Win 353: 2010-12-30 -> 2011-06-29 | Acc: 0.7222 (Thresh: 0.63) | Down Recall: 0.6000
# Win 354: 2011-06-30 -> 2011-12-28 | Acc: 0.5952 (Thresh: 0.50) | Down Recall: 0.4906
# Win 355: 2011-12-29 -> 2012-06-28 | Acc: 0.7857 (Thresh: 0.58) | Down Recall: 0.6591
# Win 356: 2012-06-29 -> 2012-12-31 | Acc: 0.6587 (Thresh: 0.58) | Down Recall: 0.5094
# Win 357: 2013-01-02 -> 2013-07-02 | Acc: 0.3492 (Thresh: 0.51) | Down Recall: 0.9744
# Win 358: 2013-07-03 -> 2013-12-31 | Acc: 0.7222 (Thresh: 0.60) | Down Recall: 0.8429
# Win 359: 2014-01-02 -> 2014-07-02 | Acc: 0.8016 (Thresh: 0.50) | Down Recall: 0.6154
# Win 360: 2014-07-03 -> 2014-12-31 | Acc: 0.6111 (Thresh: 0.51) | Down Recall: 0.6579
# Win 361: 2015-01-02 -> 2015-07-02 | Acc: 0.6349 (Thresh: 0.56) | Down Recall: 0.8205
# Win 362: 2015-07-06 -> 2015-12-31 | Acc: 0.5556 (Thresh: 0.50) | Down Recall: 0.5510
#
# ================================================================================
# SLIDING WINDOW SUMMARY (HIGH PERFORMANCE STRATEGY)
# ================================================================================
# Total Windows:    362
# Avg Accuracy:     0.5885 ± 0.0938
# Avg Down Recall:  0.7027 ± 0.2416
# Avg Threshold:    0.5227
# --------------------------------------------------------------------------------
# Min Accuracy:     0.2778 (Vào giai đoạn: 2005-06-17 -> 2005-12-14)
# Max Accuracy:     0.8413 (Vào giai đoạn: 2004-12-29 -> 2005-06-28)
# ================================================================================
